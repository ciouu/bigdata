# %% [markdown]
# <a href="https://colab.research.google.com/github/ciouu/bigdata/blob/main/0330hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  install.packages("rJava")
  install.packages("jiebaR")
  install.packages("tmcn")
  install.packages("dplyr")
  install.packages("lubridata")
  install.packages("stringr")
  install.packages("wordcloud")
  install.packages("Rwordseg",reeps="http://R-Forge.R-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘lubridata’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# ...

# %%
library("dplyr")
library("lubridate")
library("stringr")
library("jiebaR")
library("wordcloud")
# Out:
# Loading required package: jiebaRD
#
# Loading required package: RColorBrewer

# %%
#載入文字
content <- "智慧型手機功能越來越強大，電源消耗也越來越快，讓各項充電技術紛紛浮上檯面。最新就是在無線充電發展。現階段無線充電仍依賴充電盤，與真正無線充電有很大差別，無法滿足市場需求，使長距離無線充電功能持續開發。日前有研究團隊發表，透過 5G 毫米波，已可長距離無線充電，一旦商品化，將對智慧型手機應用有突破性發展。外電報導，美國喬治亞理工學院研究團隊剛宣布發明了全球第一個利用 3D 列印整流天線，大小如同撲克牌，可由 5G 毫米波訊號收取電磁波，轉成電能幫手機設備充電的裝置，讓整個 5G 網路成為廣大的無線充電系統。過去有許多研究都試圖擷取無線電波，將電磁波轉換成電能，包括電視、廣播等電波，以及Wi-Fi系統。事實證明部分應用於實驗室能為手持裝置提供最高 30% 充電功能。5G 網路廣布後，的確為長距離無線充電提供契機。據喬治亞理工學院研究團隊於《科學》期刊論文指出，5G 網路是為提供低延遲及大頻寬設計，使用 5G 毫米波頻段時可提供前所未有的高輻射功率密度，讓 5G 網路能提供長距離無線充電要大過任何系統。只是要收集 5G 毫米波的電磁波，需要龐大的整流天線裝置，並不適合手持裝置。研究團隊採用叫做 Rotman 透鏡的方式，放在天線中央位置，形狀像星星，易於從各角度收集電磁波，集合成束狀波形，增加擷取能力。天線可用 3D 列印，且可彎曲，可各角度擷取電波，效能較對照組強 21 倍。雖說從 5G 毫米波擷取電波的效能稱不上非常強大，但實驗結果顯示，天線能擷取到 6 微瓦電力，足以提供小型感測器或 IoT 裝置驅動電力。研究團隊表示，現階段 5G 網路積極布建，未來 5G 應用將無所不在，尤其都市地區，成千上萬 IoT 系統將依賴 5G 網路運行。透過長距離無線充電，可免除更換大量設備電池的問題，甚至未來產品更進一步改良強化，手持設備的耗電問題也不再是重點，廠商能有更大發展空間，成為未來 5G 時代另一項巨大商機。"
#定義斷詞器
cutter  <-  worker(bylines = F)#

# %%
cutter[content]
# Out:
#   [1] "智慧型"   "手機"     "功能"     "越來越"   "強大"     "電源"
#   [7] "消耗"     "也"       "越來越快" "讓"       "各項"     "充電"
#  [13] "技術"     "紛紛"     "浮上"     "檯面"     "最新"     "就是"
#  [19] "在"       "無線"     "充電"     "發展"     "現階段"   "無線"
#  [25] "充電"     "仍"       "依賴"     "充電"     "盤"       "與"
#  [31] "真正"     "無線"     "充電"     "有"       "很大"     "差別"
#  [37] "無法"     "滿足"     "市場需求" "使"       "長距離"   "無線"
#  [43] "充電"     "功能"     "持續"     "開發"     "日前"     "有"
#  [49] "研究"     "團隊"     "發表"     "透過"     "5"        "G"
#  [55] "毫米波"   "已"       "可"       "長距離"   "無線"     "充電"
#  [61] "一旦"     "商品化"   "將對"     "智慧型"   "手機"     "應用"
#  [67] "有"       "突破性"   "發展"     "外電報導" "美國"     "喬治亞"
#  [73] "理工學院" "研究"     "團隊"     "剛"       "宣布"     "發明"
#  [79] "了"       "全球"     "第一個"   "利用"     "3"        "D"
#  [85] "列印"     "整流"     "天線"     "大小"     "如同"     "撲克牌"
#  [91] "可"       "由"       "5"        "G"        "毫米波"   "訊號"
#  [97] "收取"     "電磁波"   "轉成"     "電能"     "幫"       "手機"
# ...

# %%
new_words<- c("應用","智慧型手機","無線充電","5G","Wi-Fi系統","充電盤","手機設備","充電裝置","充電技術","整流天線裝置")
#一次只能加入一個詞，需要搭配迴圈使用
for   (i  in 1:length (new_words)){new_user_word  (cutter,new_words[i])}

# %%
content <-str_remove_all(content,"[0-9a-zA-Z]+?")
cutter[content]
# Out:
#   [1] "智慧型手機"   "功能"         "越來越"       "強大"         "電源"
#   [6] "消耗"         "越來越快"     "各項"         "充電技術"     "紛紛"
#  [11] "浮上"         "檯面"         "最新"         "就是"         "無線充電"
#  [16] "發展"         "現階段"       "無線充電"     "依賴"         "充電盤"
#  [21] "真正"         "無線充電"     "很大"         "差別"         "無法"
#  [26] "滿足"         "市場需求"     "使"           "長距離"       "無線充電"
#  [31] "功能"         "持續"         "開發"         "日前"         "研究"
#  [36] "團隊"         "發表"         "透過"         "毫米波"       "長距離"
#  [41] "無線充電"     "一旦"         "商品化"       "將對"         "智慧型手機"
#  [46] "應用"         "突破性"       "發展"         "外電報導"     "美國"
#  [51] "喬治亞"       "理工學院"     "研究"         "團隊"         "剛"
#  [56] "宣布"         "發明"         "全球"         "第一個"       "利用"
#  [61] "列印"         "整流"         "天線"         "大小"         "如同"
#  [66] "撲克牌"       "毫米波"       "訊號"         "收取"         "電磁波"
#  [71] "轉成"         "電能"         "幫"           "手機設備"     "充電"
# ...

# %%
new_words<- c("應用","智慧型手機","無線充電","5G","Wi-Fi系統","充電盤","手機設備","充電裝置","充電技術","整流天線裝置")
writeLines(new_words, "new_words.txt")
stop_words<-c("讓","仍","了","已","由","且","也","是","各","有","的","可","在","能","為","從","將","與","於")
writeLines(stop_words, "stop_words.txt")

# %%
cutter  <-worker(user="new_words.txt",stop_word = "stop_words.txt", bylines=FALSE)
seg_words<- cutter[content]
seg_words
# Out:
#   [1] "智慧型手機"   "功能"         "越來越"       "強大"         "電源"
#   [6] "消耗"         "越來越快"     "各項"         "充電技術"     "紛紛"
#  [11] "浮上"         "檯面"         "最新"         "就是"         "無線充電"
#  [16] "發展"         "現階段"       "無線充電"     "依賴"         "充電盤"
#  [21] "真正"         "無線充電"     "很大"         "差別"         "無法"
#  [26] "滿足"         "市場需求"     "使"           "長距離"       "無線充電"
#  [31] "功能"         "持續"         "開發"         "日前"         "研究"
#  [36] "團隊"         "發表"         "透過"         "毫米波"       "長距離"
#  [41] "無線充電"     "一旦"         "商品化"       "將對"         "智慧型手機"
#  [46] "應用"         "突破性"       "發展"         "外電報導"     "美國"
#  [51] "喬治亞"       "理工學院"     "研究"         "團隊"         "剛"
#  [56] "宣布"         "發明"         "全球"         "第一個"       "利用"
#  [61] "列印"         "整流"         "天線"         "大小"         "如同"
#  [66] "撲克牌"       "毫米波"       "訊號"         "收取"         "電磁波"
#  [71] "轉成"         "電能"         "幫"           "手機設備"     "充電"
# ...

# %%
#計算詞彙頻率
txt_freq  <-freq(seg_words)
#由大到小排列
txt_freq  <-  arrange(txt_freq,desc(freq))
#檢查前5名
head(txt_freq)
# Out:
#   char     freq
# 1 無線充電 9
# 2 提供     6
# 3 研究     6
# 4 網路     6
# 5 擷取     5
# 6 團隊     5

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(showtext)

# %%
showtext.auto (enable=TRUE)

# %%
par(family = ("Microsoft YaHei"))#wordcloud需要定義字體，不然無法顯示中文
#文字雲(pkg:wordcloud)
wordcloud(txt_freq$char,txt_freq$freq,min.freq = 2,random.order = F,ordered.colors = F,colors = rainbow(nrow(txt_freq)))
# Out:
# Warning message in strwidth(words[i], cex = size[i], ...):
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in strheight(words[i], cex = size[i], ...):
# “font family 'Microsoft YaHei' not found, will use 'sans' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# ...
